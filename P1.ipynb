# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
np.random.seed(25)

# %%
house = fetch_california_housing(as_frame=True)
y = house.target
x = house.data
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
def minmax(x):
    return (x - x.min()) / (x.max() - x.min())

# %%
x_scaled = minmax(x)
y_scaled  = minmax(y)
x_scaled
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      0.539668  0.784314  0.043512   0.020469    0.008941  0.001499
# 1      0.538027  0.392157  0.038224   0.018929    0.067210  0.001141
# 2      0.466028  1.000000  0.052756   0.021940    0.013818  0.001698
# 3      0.354699  1.000000  0.035241   0.021929    0.015555  0.001493
# 4      0.230776  1.000000  0.038534   0.022166    0.015752  0.001198
# ...         ...       ...       ...        ...         ...       ...
# 20635  0.073130  0.470588  0.029769   0.023715    0.023599  0.001503
# 20636  0.141853  0.333333  0.037344   0.029124    0.009894  0.001956
# 20637  0.082764  0.313725  0.030904   0.023323    0.028140  0.001314
# 20638  0.094295  0.333333  0.031783   0.024859    0.020684  0.001152
# 20639  0.130253  0.294118  0.031252   0.024573    0.038790  0.001549
#
#        Latitude  Longitude
# 0      0.567481   0.211155
# 1      0.565356   0.212151
# 2      0.564293   0.210159
# 3      0.564293   0.209163
# 4      0.564293   0.209163
# ...         ...        ...
# 20635  0.737513   0.324701
# 20636  0.738576   0.312749
# 20637  0.732200   0.311753
# 20638  0.732200   0.301793
# 20639  0.725824   0.309761
#
# [20640 rows x 8 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y_scaled,test_size=0.2,random_state=42)

print(f"X_train: {x_train.shape} Y_train: {y_train.shape} X_test: {x_test.shape} Y_test: {y_test.shape}")
x_scaled
# Out:
# X_train: (16512, 8) Y_train: (16512,) X_test: (4128, 8) Y_test: (4128,)
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      0.539668  0.784314  0.043512   0.020469    0.008941  0.001499
# 1      0.538027  0.392157  0.038224   0.018929    0.067210  0.001141
# 2      0.466028  1.000000  0.052756   0.021940    0.013818  0.001698
# 3      0.354699  1.000000  0.035241   0.021929    0.015555  0.001493
# 4      0.230776  1.000000  0.038534   0.022166    0.015752  0.001198
# ...         ...       ...       ...        ...         ...       ...
# 20635  0.073130  0.470588  0.029769   0.023715    0.023599  0.001503
# 20636  0.141853  0.333333  0.037344   0.029124    0.009894  0.001956
# 20637  0.082764  0.313725  0.030904   0.023323    0.028140  0.001314
# 20638  0.094295  0.333333  0.031783   0.024859    0.020684  0.001152
# 20639  0.130253  0.294118  0.031252   0.024573    0.038790  0.001549
#
#        Latitude  Longitude
# 0      0.567481   0.211155
# 1      0.565356   0.212151
# 2      0.564293   0.210159
# 3      0.564293   0.209163
# 4      0.564293   0.209163
# ...         ...        ...
# 20635  0.737513   0.324701
# 20636  0.738576   0.312749
# 20637  0.732200   0.311753
# 20638  0.732200   0.301793
# 20639  0.725824   0.309761
#
# [20640 rows x 8 columns]

# %%
epochs = 20000
alpha = 0.1
w = np.random.rand(x_train.shape[1])
b = 0.0

# %%
def pred(x, w, b):
    return np.dot(x, w) + b

# %%
for i in range(epochs):
    y_pred = pred(x_train, w, b)

    error = y_pred - y_train  # shape (n,)

    dw = (2 / len(x_train)) * np.dot(x_train.T, error)   
    db = (2 / len(x_train)) * np.sum(error)

    w -= alpha * dw
    b -= alpha * db

# Epoch 18000: Error 0.0226
# Epoch 18100: Error 0.0226
# Epoch 18200: Error 0.0226
# Epoch 18300: Error 0.0226
# Epoch 18400: Error 0.0226
# Epoch 18500: Error 0.0226
# Epoch 18600: Error 0.0226
# Epoch 18700: Error 0.0226
# Epoch 18800: Error 0.0226
# Epoch 18900: Error 0.0226
# Epoch 19000: Error 0.0226
# Epoch 19100: Error 0.0226
# Epoch 19200: Error 0.0226
# Epoch 19300: Error 0.0226
# Epoch 19400: Error 0.0226
# Epoch 19500: Error 0.0226
# Epoch 19600: Error 0.0226
# Epoch 19700: Error 0.0226
# Epoch 19800: Error 0.0226
# Epoch 19900: Error 0.0226

# %%
x_test
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 20046  0.081468  0.470588  0.023720   0.020423    0.038930  0.002563
# 3024   0.140095  0.568627  0.029726   0.025499    0.043779  0.001599
# 15663  0.205528  1.000000  0.022196   0.025273    0.036632  0.000538
# 20484  0.361216  0.313725  0.037696   0.020362    0.047703  0.002215
# 9814   0.222418  0.647059  0.032942   0.020594    0.029709  0.001442
# ...         ...       ...       ...        ...         ...       ...
# 15362  0.283106  0.294118  0.043641   0.021730    0.037781  0.001848
# 16623  0.153563  0.529412  0.037471   0.027374    0.046162  0.001326
# 18086  0.602054  0.470588  0.045310   0.018197    0.044340  0.001688
# 2144   0.157591  0.686275  0.031496   0.019263    0.034306  0.001526
# 3665   0.210494  0.313725  0.022279   0.020755    0.046750  0.002444
#
#        Latitude  Longitude
# 20046  0.374070   0.531873
# 3024   0.276302   0.487052
# 15663  0.558980   0.190239
# 20484  0.184910   0.560757
# 9814   0.433581   0.241036
# ...         ...        ...
# 15362  0.087141   0.710159
# 16623  0.299681   0.350598
# 18086  0.506908   0.229084
# 2144   0.449522   0.457171
# 3665   0.178533   0.595618
#
# [4128 rows x 8 columns]

# %%
final_pred = pred(x_test,w,b)

# %%
y_min = y.min()
y_max = y.max()


y_test_real = y_test * (y_max - y_min) + y_min
final_pred_real = final_pred * (y_max - y_min) + y_min
from sklearn.metrics import r2_score
r2 = r2_score(y_test, final_pred)
print(f"R2 score:{r2:.2f}")

mae = np.mean(np.abs(y_test_real - final_pred_real)) * 100000
actual_error = np.mean(np.abs(y_test_real - final_pred_real))
print("Actual in dollars:", actual_error)

print("MAE in dollars:", mae)
# Out:
# R2 score:0.58
# Actual in dollars: 0.5413651581863382
# MAE in dollars: 54136.51581863382

# %%
final_pred = pd.DataFrame(final_pred,columns=["MedHouseVal"])
final_pred
# Out:
#       MedHouseVal
# 0        0.120139
# 1        0.330742
# 2        0.482784
# 3        0.562954
# 4        0.526618
# ...           ...
# 4123     0.417724
# 4124     0.454883
# 4125     0.885229
# 4126     0.234340
# 4127     0.361967
#
# [4128 rows x 1 columns]

# %%
y_test = pd.DataFrame(y_test, columns=["MedHouseVal"])
y_test
# Out:
#        MedHouseVal
# 20046     0.067424
# 3024      0.063507
# 15663     1.000000
# 20484     0.419794
# 9814      0.542268
# ...            ...
# 15362     0.511959
# 16623     0.519175
# 18086     1.000000
# 2144      0.118146
# 3665      0.281444
#
# [4128 rows x 1 columns]
